# %%
blocks= ["didihat","ganaolihat","munsiyari","kanalichina"]
for block in blocks:
    print("UKIHDP review for:", block)
# Out:
# UKIHDP review for: didihat
# UKIHDP review for: ganaolihat
# UKIHDP review for: munsiyari
# UKIHDP review for: kanalichina

# %%
blocks= ["didihat","ganaolihat","munsiyari","kanalichina"]
for block in blocks:
    print(block)  
    print("monthly report pending")
# Out:
# didihat
# monthly report pending
# ganaolihat
# monthly report pending
# munsiyari
# monthly report pending
# kanalichina
# monthly report pending

# %%
farmers= [12,18,25,30]
for number in farmers:
    print(number*2)
# Out:
# 24
# 36
# 50
# 60

# %%
farmer={
    "name":"geeta",
    "block":"gangolihat",
    "crop":"apple",
    "area":1.2
}
farmer
# Out:
# {'name': 'geeta', 'block': 'gangolihat', 'crop': 'apple', 'area': 1.2}

# %%
print(farmer["name"])
# Out:
# geeta

# %%
print("farmer",farmer["name"],"is growing",farmer["crop"])
# Out:
# farmer geeta is growing apple

# %%
farmer["crop"]= "malta"

# %%
print(farmer)
# Out:
# {'name': 'geeta', 'block': 'gangolihat', 'crop': 'malta', 'area': 1.2}

# %%
farmers=[
    {"name":"mohan", "block":"didihat","crop":"potato"},
    {"name":"geeta", "block":"gangolihat","crop":"apple"},
    {"name":"sohan","block":"munsiyari","crop":"pea"}
]
farmers
# Out:
# [{'name': 'mohan', 'block': 'didihat', 'crop': 'potato'},
#  {'name': 'geeta', 'block': 'gangolihat', 'crop': 'apple'},
#  {'name': 'sohan', 'block': 'munsiyari', 'crop': 'pea'}]

# %%
farmers[0]["mob no."] = "12"
farmers[1]["mob no."] = "13"
farmers[2]["mob no."] = "14"
(farmers)
# Out:
# [{'name': 'mohan', 'block': 'didihat', 'crop': 'potato', 'mob no.': '12'},
#  {'name': 'geeta', 'block': 'gangolihat', 'crop': 'apple', 'mob no.': '13'},
#  {'name': 'sohan', 'block': 'munsiyari', 'crop': 'pea', 'mob no.': '14'}]

# %%
for farmer in farmers:
    print("farmer:", farmer["name"])
    print("block:", farmer["block"])
    print("crop:", farmer["crop"])
    print("--------")
# Out:
# farmer: mohan
# block: didihat
# crop: potato
# --------
# farmer: geeta
# block: gangolihat
# crop: apple
# --------
# farmer: sohan
# block: munsiyari
# crop: pea
# --------

# %%
farmers={
    "name":["mohan","geeta","sohan"],
    "block":["didihat","gangolihat","munsiyari"],
    "crop":["potato","apple","pea"]
}
farmers
# Out:
# {'name': ['mohan', 'geeta', 'sohan'],
#  'block': ['didihat', 'gangolihat', 'munsiyari'],
#  'crop': ['potato', 'apple', 'pea']}

# %%
farmers["mob no.:"]= [12,25,23]
farmers
# Out:
# {'name': ['mohan', 'geeta', 'sohan'],
#  'block': ['didihat', 'gangolihat', 'munsiyari'],
#  'crop': ['potato', 'apple', 'pea'],
#  'mob no.:': [12, 25, 23]}

# %%
import pandas as pd
farmers={
    "name":["mohan","geeta","sohan"],
    "block":["didihat","gangolihat","munsiyari"],
    "crop":["potato","apple","pea"]
}
df=pd.DataFrame(farmers)
df
# Out:
#     name       block    crop
# 0  mohan     didihat  potato
# 1  geeta  gangolihat   apple
# 2  sohan   munsiyari     pea

# %%
df["mob no."]= [25,26,27]
df
# Out:
#     name       block    crop  mob no.
# 0  mohan     didihat  potato       25
# 1  geeta  gangolihat   apple       26
# 2  sohan   munsiyari     pea       27
